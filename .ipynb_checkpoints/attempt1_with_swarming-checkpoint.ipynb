# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.io
from operator import itemgetter
import pandas as pd
from sklearn.cross_validation import train_test_split

import csv
import nupic

# %%
traindf = pd.read_csv('./lab_data/24chan/24chan_train1.csv', header = 0, skiprows = [1,2])
testdf = pd.read_csv('./lab_data/24chan/24chan_test1.csv', header = 0, skiprows = [1,2])

print traindf.shape
print traindf.head()
# Out:
# (67480, 24)
#         field1       field2       field3      field4      field5      field6  \
# 0 -3025.031006 -3898.197510 -5941.647461 -143.265717  223.767761 -896.394226
# 1 -3025.013184 -3900.128662 -5938.768555 -139.367584  225.287674 -896.894958
# 2 -3025.192139 -3902.274414 -5937.176758 -138.205292  225.430725 -896.054504
# 3 -3022.474121 -3898.537109 -5932.116699 -136.184692  228.291748 -893.175598
# 4 -3019.648682 -3890.043457 -5928.969238 -131.589172  232.779984 -891.941772
#
#          field7       field8        field9      field10       ...        \
# 0 -11081.028320 -9336.876953 -50944.109375 -8007.466797       ...
# 1 -11080.598633 -9336.948242 -50917.480469 -8008.665039       ...
# 2 -11080.205078 -9336.787109 -50951.457031 -8010.721191       ...
# 3 -11071.533203 -9329.348633 -50996.410156 -8014.029297       ...
# 4 -11068.529297 -9326.237305 -50985.449219 -8013.957520       ...
#
#         field16      field17      field18     field19      field20  \
# 0 -31958.019531 -2176.916504  1054.269043 -278.681519 -7274.222168
# 1 -31957.037109 -2177.864258  1053.464355 -279.504059 -7277.244141
# 2 -32048.822266 -2177.703369  1055.860474 -267.416229 -7268.804199
# 3 -32114.500000 -2170.890625  1055.306152 -272.262085 -7271.772461
# 4 -32055.687500 -2166.974609  1051.783569 -292.736298 -7280.552246
#
#        field21      field22       field23   field24  classification
# 0 -3945.225586 -6778.085449 -13151.800781 -0.017881               1
# 1 -3948.301025 -6778.389160 -13150.459961 -0.017881               1
# 2 -3945.547363 -6757.933105 -13144.469727 -0.017881               1
# 3 -3944.420898 -6781.822266 -13149.744141 -0.017881               1
# 4 -3941.345215 -6793.892578 -13160.133789 -0.017881               1
#
# [5 rows x 24 columns]

# %%
traindf.describe()
# Out:
#              field1        field2        field3        field4        field5  \
# count  67480.000000  67480.000000  67480.000000  67480.000000  67480.000000
# mean   -3283.917799  -3658.287853  -5900.545595    192.018548    269.597454
# std      182.540156    129.933681     82.244385    166.008104     22.352831
# min    -3648.394287  -3930.258789  -5998.581543   -147.789719      0.000000
# 25%    -3428.614258  -3725.950500  -5934.583984     80.555679    255.453583
# 50%    -3259.554565  -3633.615356  -5908.834961    186.225769    275.284058
# 75%    -3126.454346  -3554.476746  -5866.902832    352.397552    286.889069
# max        0.000000      0.000000      0.000000    453.811890    314.426422
#
#              field6        field7        field8        field9       field10  \
# count  67480.000000  67480.000000  67480.000000  67480.000000  67480.000000
# mean    -940.131160 -10884.435966  -8987.949700 -49178.084116  -8079.236128
# std       33.169965    145.501240    177.245078   2161.673437    116.426714
# min    -1015.716797 -11086.375000  -9336.948242 -52709.589844  -8247.095703
# 25%     -946.444275 -10907.743652  -9095.997070 -50648.536133  -8131.438477
# 50%     -930.368896 -10868.382812  -8958.541992 -50310.025391  -8080.914551
# 75%     -919.336060 -10847.944336  -8881.008789 -47898.653320  -8019.519043
# max        0.000000      0.000000      0.000000      0.000000      0.000000
#
#             ...             field16       field17       field18       field19  \
# count       ...        67480.000000  67480.000000  67480.000000  67480.000000
# mean        ...       -31609.041948  -1561.742850   1093.703688   -118.842202
# std         ...          763.512907    277.183027     31.741405     90.313884
# min         ...       -32720.804688  -2177.864258      0.000000   -292.736298
# 25%         ...       -32245.195312  -1762.774567   1063.616608   -182.220337
# 50%         ...       -31583.592773  -1522.278748   1103.746948   -108.951332
# 75%         ...       -31054.540527  -1318.301300   1114.654541    -35.476685
# max         ...            0.000000      0.000000   1144.909912     27.501583
#
#             field20       field21       field22       field23       field24  \
# count  67480.000000  67480.000000  67480.000000  67480.000000  67480.000000
# mean   -7244.787349  -3434.940191  -6818.229873 -13077.514964     -0.017879
# std       90.445562    265.782947     90.625826    168.937326      0.000218
# min    -7302.904297  -3948.301025  -6918.311035 -13195.216797     -0.017881
# 25%    -7257.968262  -3635.707458  -6848.019531 -13137.156250     -0.017881
# 50%    -7244.414062  -3417.483032  -6814.849609 -13062.527832     -0.017881
# 75%    -7233.435059  -3209.598328  -6785.666992 -13027.578125     -0.017881
# max        0.000000      0.000000      0.000000      0.000000      0.000000
#
#        classification
# count    67480.000000
# mean         1.002238
# std          0.817573
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          2.000000
#
# [8 rows x 24 columns]

# %%
# SWARM_CONFIG = {
#     "includedFields": [
#         {
#             'fieldName': u'field1',
#             #'name': u'field1',
#             #'n': 521,
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0
#             #'w': 21
#         },
#         {
#             'fieldName': u'field2',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field3',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field4',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0
#             },
#         {
#             'fieldName': u'field5',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field6',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field7',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field8',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field9',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field10',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field11',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field12',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field13',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field14',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field15',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field16',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field17',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field18',
#             'fieldType': 'float',
#             'minValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field19',
#             'fieldType': 'float',
#             'maxValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field20',
#             'fieldType': 'float',
#             'maxValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field21',
#             'fieldType': 'float',
#             'maxValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field22',
#             'fieldType': 'float',
#             'maxValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field23',
#             'fieldType': 'float',
#             'maxValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             'fieldName': u'field24',
#             'fieldType': 'float',
#             'maxValue': 100000.0,
#             'minValue': -100000.0},
#         {
#             #'classifierOnly': True,
#             'fieldName': u'classification',
#             'fieldType': 'int'}
#     ],
#     "streamDef": {
#         "info": "classification_24channels",
#         "version": 1,
#         "streams": [
#             {
#                 "info": "sine.csv",
#                 "source": "file:///home/polina/Documents/hse/course_work/lab_data/24chan/24chan_train1.csv",
#                 "columns": [
#                   "*"
#                 ]
#             }
#         ]
#     },
#     "inferenceType": "NontemporalClassification",
#     "inferenceArgs": {
#         "predictionSteps": [
#           0
#         ],
#         "predictedField": u'classification'
#     },
#     "swarmSize": "medium"
# }

# %%
SWARM_CONFIG = {
    "includedFields": [
        {
            'fieldName': u'field1',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field2',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field3',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field4',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0
            },
        {
            'fieldName': u'field5',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field6',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field7',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field8',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field9',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field10',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field11',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field12',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field13',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field15',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field16',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field17',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field18',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field19',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field20',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field21',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field22',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field23',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            'fieldName': u'field24',
            'fieldType': 'float',
            'maxValue': 100000.0,
            'minValue': -100000.0},
        {
            #'classifierOnly': True,
            'fieldName': u'classification',
            'fieldType': 'int'}
    ],
    "streamDef": {
        "info": "classification_24channels",
        "version": 1,
        "streams": [
            {
                "info": "sine.csv",
                "source": "file:///home/polina/Documents/hse/course_work/lab_data/24chan/24chan_train1.csv",
                "columns": [
                  "*"
                ]
            }
        ]
    },
    "inferenceType": "NontemporalClassification",
    "inferenceArgs": {
        "predictionSteps": [
          0
        ],
        "predictedField": u'classification'
    },
    "swarmSize": "medium"
}

# %%
from nupic.swarming import permutations_runner
from nupic.swarming.permutations_runner import DEFAULT_OPTIONS
import nupic.swarming

# %%
def swarm_over_data():
    return nupic.swarming.permutations_runner.runWithConfig(SWARM_CONFIG, {'maxWorkers': 8, 'overwrite': True})


#input_file = "./lab_data/24chan/24chan_train1.csv"
model_params = swarm_over_data()
# Out:
# Generating experiment files in directory: /home/polina/Documents/hse/course_work...
# Writing  313 lines...
# Writing  114 lines...
# done.
# None
# Successfully submitted new HyperSearch job, jobID=1010
# ##>> UPDATED WORKER STATE:
# {   u'activeSwarms': [   u'modelParams|sensorParams|encoders|field8',
#                          u'modelParams|sensorParams|encoders|field9',
#                          u'modelParams|sensorParams|encoders|field6',
#                          u'modelParams|sensorParams|encoders|field7',
#                          u'modelParams|sensorParams|encoders|field4',
#                          u'modelParams|sensorParams|encoders|field5',
#                          u'modelParams|sensorParams|encoders|field2',
#                          u'modelParams|sensorParams|encoders|field3',
#                          u'modelParams|sensorParams|encoders|field1',
#                          u'modelParams|sensorParams|encoders|field18',
#                          u'modelParams|sensorParams|encoders|field19',
#                          u'modelParams|sensorParams|encoders|field15',
#                          u'modelParams|sensorParams|encoders|field16',
#                          u'modelParams|sensorParams|encoders|field17',
#                          u'modelParams|sensorParams|encoders|field10',
#                          u'modelParams|sensorParams|encoders|field11',
#                          u'modelParams|sensorParams|encoders|field12',
#                          u'modelParams|sensorParams|encoders|field13',
#                          u'modelParams|sensorParams|encoders|field24',
#                          u'modelParams|sensorParams|encoders|field21',
#                          u'modelParams|sensorParams|encoders|field20',
#                          u'modelParams|sensorParams|encoders|field23',
#                          u'modelParams|sensorParams|encoders|field22'],
#     u'blackListedEncoders': [],
#     u'lastGoodSprint': None,
#     u'lastUpdateTime': 1464093466.163966,
#     u'searchOver': False,
#     u'sprints': [   {   u'bestErrScore': None,
#                         u'bestModelId': None,
#                         u'status': u'active'}],
#     u'swarms': {   u'modelParams|sensorParams|encoders|field1': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field10': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field11': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field12': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field13': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field15': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field16': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field17': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field18': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field19': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field2': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field20': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field21': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field22': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field23': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field24': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field3': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field4': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field5': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field6': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field7': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field8': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field9': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'}}}
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8030,
#     u'bestValue': 50.0,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.5,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 50.0},
#     u'saved': False} (elapsed time: 19.3054 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8030,
#     u'bestValue': 1.0,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.01,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 1.0},
#     u'saved': False} (elapsed time: 20.3514 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8030,
#     u'bestValue': 0.5,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.005,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 0.5},
#     u'saved': False} (elapsed time: 22.3988 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8030,
#     u'bestValue': 0.25,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.0025,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 0.25},
#     u'saved': False} (elapsed time: 23.4288 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8030,
#     u'bestValue': 0.2,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.002,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 0.2},
#     u'saved': False} (elapsed time: 24.4666 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8030,
#     u'bestValue': 0.16666666666666666,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.0016666666666666668,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 0.16666666666666666},
#     u'saved': False} (elapsed time: 25.4883 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8030,
#     u'bestValue': 0.14285714285714285,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.0014285714285714286,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 0.14285714285714285},
#     u'saved': False} (elapsed time: 26.5169 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8030,
#     u'bestValue': 0.125,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.00125,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 0.125},
#     u'saved': False} (elapsed time: 27.5449 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8030,
#     u'bestValue': 0.1111111111111111,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.0011111111111111111,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 0.1111111111111111},
#     u'saved': False} (elapsed time: 28.5729 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8030,
#     u'bestValue': 0.1,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.001,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 0.1},
#     u'saved': False} (elapsed time: 29.6008 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8030,
#     u'bestValue': 0.0,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.0,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 0.0},
#     u'saved': False} (elapsed time: 30.6288 secs)
# <jobID: 1010> 1  models finished [success: 1; EOF: 1; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8039,
#     u'bestValue': 0.0,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.0,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 0.0},
#     u'saved': True} (elapsed time: 50.1693 secs)
# <jobID: 1010> 2  models finished [success: 2; EOF: 2; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 3  models finished [success: 3; EOF: 3; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 4  models finished [success: 4; EOF: 4; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 5  models finished [success: 5; EOF: 5; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 7  models finished [success: 7; EOF: 7; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 8  models finished [success: 8; EOF: 8; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 9  models finished [success: 9; EOF: 9; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 10  models finished [success: 10; EOF: 10; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 11  models finished [success: 11; EOF: 11; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 12  models finished [success: 12; EOF: 12; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 13  models finished [success: 13; EOF: 13; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 14  models finished [success: 14; EOF: 14; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 15  models finished [success: 15; EOF: 15; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 16  models finished [success: 16; EOF: 16; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 17  models finished [success: 17; EOF: 17; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 18  models finished [success: 18; EOF: 18; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 19  models finished [success: 19; EOF: 19; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 20  models finished [success: 20; EOF: 20; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 21  models finished [success: 21; EOF: 21; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 22  models finished [success: 22; EOF: 22; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 23  models finished [success: 23; EOF: 23; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 24  models finished [success: 24; EOF: 24; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 25  models finished [success: 25; EOF: 25; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 26  models finished [success: 26; EOF: 26; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 27  models finished [success: 27; EOF: 27; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 28  models finished [success: 28; EOF: 28; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 29  models finished [success: 29; EOF: 29; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 30  models finished [success: 30; EOF: 30; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 32  models finished [success: 32; EOF: 32; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 33  models finished [success: 33; EOF: 33; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 34  models finished [success: 34; EOF: 34; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 35  models finished [success: 35; EOF: 35; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 36  models finished [success: 36; EOF: 36; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 37  models finished [success: 37; EOF: 37; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 38  models finished [success: 38; EOF: 38; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 39  models finished [success: 39; EOF: 39; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 40  models finished [success: 40; EOF: 40; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 41  models finished [success: 41; EOF: 41; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 42  models finished [success: 42; EOF: 42; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 43  models finished [success: 43; EOF: 43; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 44  models finished [success: 44; EOF: 44; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 46  models finished [success: 46; EOF: 46; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 47  models finished [success: 47; EOF: 47; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 48  models finished [success: 48; EOF: 48; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 49  models finished [success: 49; EOF: 49; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 50  models finished [success: 50; EOF: 50; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 51  models finished [success: 51; EOF: 51; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 52  models finished [success: 52; EOF: 52; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 53  models finished [success: 53; EOF: 53; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 54  models finished [success: 54; EOF: 54; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 55  models finished [success: 55; EOF: 55; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 56  models finished [success: 56; EOF: 56; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 57  models finished [success: 57; EOF: 57; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 58  models finished [success: 58; EOF: 58; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 59  models finished [success: 59; EOF: 59; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 60  models finished [success: 60; EOF: 60; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 61  models finished [success: 61; EOF: 61; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 62  models finished [success: 62; EOF: 62; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 63  models finished [success: 63; EOF: 63; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 64  models finished [success: 64; EOF: 64; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 65  models finished [success: 65; EOF: 65; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 66  models finished [success: 66; EOF: 66; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 67  models finished [success: 67; EOF: 67; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 68  models finished [success: 68; EOF: 68; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 69  models finished [success: 69; EOF: 69; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 70  models finished [success: 70; EOF: 70; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 72  models finished [success: 72; EOF: 72; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 73  models finished [success: 73; EOF: 73; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 74  models finished [success: 74; EOF: 74; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 75  models finished [success: 75; EOF: 75; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 76  models finished [success: 76; EOF: 76; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 77  models finished [success: 77; EOF: 77; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 78  models finished [success: 78; EOF: 78; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 80  models finished [success: 80; EOF: 80; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 81  models finished [success: 81; EOF: 81; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 82  models finished [success: 82; EOF: 82; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 83  models finished [success: 83; EOF: 83; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 84  models finished [success: 84; EOF: 84; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 85  models finished [success: 85; EOF: 85; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 86  models finished [success: 86; EOF: 86; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 87  models finished [success: 87; EOF: 87; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 88  models finished [success: 88; EOF: 88; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 89  models finished [success: 89; EOF: 89; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 90  models finished [success: 90; EOF: 90; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 91  models finished [success: 91; EOF: 91; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 92  models finished [success: 92; EOF: 92; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 93  models finished [success: 93; EOF: 93; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field1' with a best errScore of 0
# <jobID: 1010> 94  models finished [success: 94; EOF: 94; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field10' with a best errScore of 0
# <jobID: 1010> 95  models finished [success: 95; EOF: 95; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field11' with a best errScore of 0
# <jobID: 1010> 96  models finished [success: 96; EOF: 96; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field12' with a best errScore of 0
# <jobID: 1010> 97  models finished [success: 97; EOF: 97; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field13' with a best errScore of 0
# <jobID: 1010> 98  models finished [success: 98; EOF: 98; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field12' with a best errScore of 0
# <jobID: 1010> 99  models finished [success: 99; EOF: 99; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field16' with a best errScore of 0
# <jobID: 1010> 100  models finished [success: 100; EOF: 100; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field17' with a best errScore of 0
# <jobID: 1010> 101  models finished [success: 101; EOF: 101; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field18' with a best errScore of 0
# <jobID: 1010> 102  models finished [success: 102; EOF: 102; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field19' with a best errScore of 0
# <jobID: 1010> 103  models finished [success: 103; EOF: 103; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field2' with a best errScore of 0
# <jobID: 1010> 104  models finished [success: 104; EOF: 104; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field20' with a best errScore of 0
# <jobID: 1010> 105  models finished [success: 105; EOF: 105; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field21' with a best errScore of 0
# <jobID: 1010> 107  models finished [success: 107; EOF: 107; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field24' with a best errScore of 0
# <jobID: 1010> 108  models finished [success: 108; EOF: 108; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field22' with a best errScore of 0
# <jobID: 1010> 109  models finished [success: 109; EOF: 109; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field3' with a best errScore of 0
# <jobID: 1010> 110  models finished [success: 110; EOF: 110; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field4' with a best errScore of 0
# <jobID: 1010> 111  models finished [success: 111; EOF: 111; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field5' with a best errScore of 0
# <jobID: 1010> 112  models finished [success: 112; EOF: 112; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field21' with a best errScore of 0
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field6' with a best errScore of 0
# <jobID: 1010> 113  models finished [success: 113; EOF: 113; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field7' with a best errScore of 0
# <jobID: 1010> 114  models finished [success: 114; EOF: 114; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field8' with a best errScore of 0
# <jobID: 1010> 116  models finished [success: 116; EOF: 116; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field3' with a best errScore of 0
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field9' with a best errScore of 0
# <jobID: 1010> 117  models finished [success: 117; EOF: 117; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field4' with a best errScore of 0
# ##>> UPDATED STATUS:
# Completed generation #0 of swarm 'modelParams|sensorParams|encoders|field9' with a best errScore of 0
# <jobID: 1010> 118  models finished [success: 118; EOF: 118; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 120  models finished [success: 120; EOF: 120; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 121  models finished [success: 121; EOF: 121; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 122  models finished [success: 122; EOF: 122; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 123  models finished [success: 123; EOF: 123; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 124  models finished [success: 124; EOF: 124; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 126  models finished [success: 126; EOF: 126; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 127  models finished [success: 127; EOF: 127; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 128  models finished [success: 128; EOF: 128; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 129  models finished [success: 129; EOF: 129; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 130  models finished [success: 130; EOF: 130; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 131  models finished [success: 131; EOF: 131; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 132  models finished [success: 132; EOF: 132; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 133  models finished [success: 133; EOF: 133; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 134  models finished [success: 134; EOF: 134; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 135  models finished [success: 135; EOF: 135; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 136  models finished [success: 136; EOF: 136; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 137  models finished [success: 137; EOF: 137; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 138  models finished [success: 138; EOF: 138; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 139  models finished [success: 139; EOF: 139; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 141  models finished [success: 141; EOF: 141; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 142  models finished [success: 142; EOF: 142; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 143  models finished [success: 143; EOF: 143; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 144  models finished [success: 144; EOF: 144; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 145  models finished [success: 145; EOF: 145; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 146  models finished [success: 146; EOF: 146; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 149  models finished [success: 149; EOF: 149; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 150  models finished [success: 150; EOF: 150; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 151  models finished [success: 151; EOF: 151; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 152  models finished [success: 152; EOF: 152; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 153  models finished [success: 153; EOF: 153; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 154  models finished [success: 154; EOF: 154; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 156  models finished [success: 156; EOF: 156; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 157  models finished [success: 157; EOF: 157; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 158  models finished [success: 158; EOF: 158; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 159  models finished [success: 159; EOF: 159; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 160  models finished [success: 160; EOF: 160; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 161  models finished [success: 161; EOF: 161; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 162  models finished [success: 162; EOF: 162; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 163  models finished [success: 163; EOF: 163; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 164  models finished [success: 164; EOF: 164; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 165  models finished [success: 165; EOF: 165; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 166  models finished [success: 166; EOF: 166; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 167  models finished [success: 167; EOF: 167; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 168  models finished [success: 168; EOF: 168; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 169  models finished [success: 169; EOF: 169; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 170  models finished [success: 170; EOF: 170; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 171  models finished [success: 171; EOF: 171; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 172  models finished [success: 172; EOF: 172; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 173  models finished [success: 173; EOF: 173; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 174  models finished [success: 174; EOF: 174; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 175  models finished [success: 175; EOF: 175; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 176  models finished [success: 176; EOF: 176; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 177  models finished [success: 177; EOF: 177; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 178  models finished [success: 178; EOF: 178; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 179  models finished [success: 179; EOF: 179; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 180  models finished [success: 180; EOF: 180; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 181  models finished [success: 181; EOF: 181; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 182  models finished [success: 182; EOF: 182; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 183  models finished [success: 183; EOF: 183; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 184  models finished [success: 184; EOF: 184; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 185  models finished [success: 185; EOF: 185; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 186  models finished [success: 186; EOF: 186; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 187  models finished [success: 187; EOF: 187; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 188  models finished [success: 188; EOF: 188; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 189  models finished [success: 189; EOF: 189; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 190  models finished [success: 190; EOF: 190; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 191  models finished [success: 191; EOF: 191; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 192  models finished [success: 192; EOF: 192; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 193  models finished [success: 193; EOF: 193; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 194  models finished [success: 194; EOF: 194; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 195  models finished [success: 195; EOF: 195; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 196  models finished [success: 196; EOF: 196; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 197  models finished [success: 197; EOF: 197; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 198  models finished [success: 198; EOF: 198; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 199  models finished [success: 199; EOF: 199; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1010> 200  models finished [success: 200; EOF: 200; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ####>> UPDATED JOB RESULTS:
# {   u'absoluteFieldContributions': {   u'field1': 1e-05,
#                                        u'field10': 1e-05,
#                                        u'field11': 1e-05,
#                                        u'field12': 1e-05,
#                                        u'field13': 1e-05,
#                                        u'field15': 1e-05,
#                                        u'field16': 1e-05,
#                                        u'field17': 1e-05,
#                                        u'field18': 1e-05,
#                                        u'field19': 1e-05,
#                                        u'field2': 1e-05,
#                                        u'field20': 1e-05,
#                                        u'field21': 1e-05,
#                                        u'field22': 1e-05,
#                                        u'field23': 1e-05,
#                                        u'field24': 1e-05,
#                                        u'field3': 1e-05,
#                                        u'field4': 1e-05,
#                                        u'field5': 1e-05,
#                                        u'field6': 1e-05,
#                                        u'field7': 1e-05,
#                                        u'field8': 1e-05,
#                                        u'field9': 1e-05},
#     u'bestModel': 8039,
#     u'bestValue': 0.0,
#     u'fieldContributions': {   u'field1': 100.0,
#                                u'field10': 100.0,
#                                u'field11': 100.0,
#                                u'field12': 100.0,
#                                u'field13': 100.0,
#                                u'field15': 100.0,
#                                u'field16': 100.0,
#                                u'field17': 100.0,
#                                u'field18': 100.0,
#                                u'field19': 100.0,
#                                u'field2': 100.0,
#                                u'field20': 100.0,
#                                u'field21': 100.0,
#                                u'field22': 100.0,
#                                u'field23': 100.0,
#                                u'field24': 100.0,
#                                u'field3': 100.0,
#                                u'field4': 100.0,
#                                u'field5': 100.0,
#                                u'field6': 100.0,
#                                u'field7': 100.0,
#                                u'field8': 100.0,
#                                u'field9': 100.0},
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.0,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 0.0},
#     u'saved': True} (elapsed time: 1782.7 secs)
# Evaluated 200 models
# HyperSearch finished!
# Worker completion message: None
#
# Results from all experiments:
# ----------------------------------------------------------------
# Generating experiment files in directory: /tmp/tmp3Hll9J...
# Writing  313 lines...
# Writing  114 lines...
# done.
# None
# [0] Experiment _NupicModelInfo(jobID=1010, modelID=8030, status=completed, completionReason=eof, updateCounter=77, numRecords=4000)
# (modelParams|sensorParams|encoders|field1:n_272.modelParams|clParams|alpha_0.05005.modelParams|sensorParams|encoders|_classifierInput|n_275):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [1] Experiment _NupicModelInfo(jobID=1010, modelID=8039, status=completed, completionReason=eof, updateCounter=46, numRecords=4000)
# (modelParams|sensorParams|encoders|field10:n_272.modelParams|sensorParams|encoders|_classifierInput|n_275.modelParams|clParams|alpha_0.05005):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [2] Experiment _NupicModelInfo(jobID=1010, modelID=8092, status=completed, completionReason=eof, updateCounter=47, numRecords=4000)
# (modelParams|clParams|alpha_0.05005.modelParams|sensorParams|encoders|_classifierInput|n_275.modelParams|sensorParams|encoders|field11:n_272):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [3] Experiment _NupicModelInfo(jobID=1010, modelID=8093, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field12:n_272.modelParams|clParams|alpha_0.05005.modelParams|sensorParams|encoders|_classifierInput|n_275):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [4] Experiment _NupicModelInfo(jobID=1010, modelID=8134, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.05005.modelParams|sensorParams|encoders|_classifierInput|n_275.modelParams|sensorParams|encoders|field13:n_272):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [5] Experiment _NupicModelInfo(jobID=1010, modelID=8165, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.05005.modelParams|sensorParams|encoders|field15:n_272.modelParams|sensorParams|encoders|_classifierInput|n_275):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [6] Experiment _NupicModelInfo(jobID=1010, modelID=8186, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|_classifierInput|n_275.modelParams|clParams|alpha_0.05005.modelParams|sensorParams|encoders|field16:n_272):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [7] Experiment _NupicModelInfo(jobID=1010, modelID=8197, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field17:n_272.modelParams|clParams|alpha_0.05005.modelParams|sensorParams|encoders|_classifierInput|n_275):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [8] Experiment _NupicModelInfo(jobID=1010, modelID=8198, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.05005.modelParams|sensorParams|encoders|_classifierInput|n_275.modelParams|sensorParams|encoders|field18:n_272):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [9] Experiment _NupicModelInfo(jobID=1010, modelID=8199, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.05005.modelParams|sensorParams|encoders|_classifierInput|n_275.modelParams|sensorParams|encoders|field19:n_272):
# ...
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [172] Experiment _NupicModelInfo(jobID=1010, modelID=8452, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0605752494518.modelParams|sensorParams|encoders|_classifierInput|n_297.modelParams|sensorParams|encoders|field20:n_279):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [173] Experiment _NupicModelInfo(jobID=1010, modelID=8453, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field21:n_279.modelParams|sensorParams|encoders|_classifierInput|n_297.modelParams|clParams|alpha_0.0605752494518):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [174] Experiment _NupicModelInfo(jobID=1010, modelID=8454, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0515145442413.modelParams|sensorParams|encoders|_classifierInput|n_297.modelParams|sensorParams|encoders|field22:n_325):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [175] Experiment _NupicModelInfo(jobID=1010, modelID=8455, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field23:n_279.modelParams|clParams|alpha_0.0605752494518.modelParams|sensorParams|encoders|_classifierInput|n_297):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [176] Experiment _NupicModelInfo(jobID=1010, modelID=8456, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0605752494518.modelParams|sensorParams|encoders|field24:n_279.modelParams|sensorParams|encoders|_classifierInput|n_297):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [177] Experiment _NupicModelInfo(jobID=1010, modelID=8457, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0605752494518.modelParams|sensorParams|encoders|field3:n_279.modelParams|sensorParams|encoders|_classifierInput|n_297):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [178] Experiment _NupicModelInfo(jobID=1010, modelID=8458, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field4:n_279.modelParams|clParams|alpha_0.0605752494518.modelParams|sensorParams|encoders|_classifierInput|n_297):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [179] Experiment _NupicModelInfo(jobID=1010, modelID=8459, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0605752494518.modelParams|sensorParams|encoders|_classifierInput|n_297.modelParams|sensorParams|encoders|field5:n_279):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [180] Experiment _NupicModelInfo(jobID=1010, modelID=8460, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field6:n_279.modelParams|sensorParams|encoders|_classifierInput|n_297.modelParams|clParams|alpha_0.0605752494518):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [181] Experiment _NupicModelInfo(jobID=1010, modelID=8461, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0605752494518.modelParams|sensorParams|encoders|_classifierInput|n_297.modelParams|sensorParams|encoders|field7:n_279):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [182] Experiment _NupicModelInfo(jobID=1010, modelID=8462, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|_classifierInput|n_297.modelParams|clParams|alpha_0.0605752494518.modelParams|sensorParams|encoders|field8:n_279):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [183] Experiment _NupicModelInfo(jobID=1010, modelID=8463, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field9:n_279.modelParams|clParams|alpha_0.0605752494518.modelParams|sensorParams|encoders|_classifierInput|n_297):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [184] Experiment _NupicModelInfo(jobID=1010, modelID=8464, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field1:n_233.modelParams|clParams|alpha_0.0468202278794.modelParams|sensorParams|encoders|_classifierInput|n_227):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [185] Experiment _NupicModelInfo(jobID=1010, modelID=8465, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field10:n_256.modelParams|sensorParams|encoders|_classifierInput|n_227.modelParams|clParams|alpha_0.0422898752741):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [186] Experiment _NupicModelInfo(jobID=1010, modelID=8466, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0422898752741.modelParams|sensorParams|encoders|_classifierInput|n_227.modelParams|sensorParams|encoders|field11:n_256):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [187] Experiment _NupicModelInfo(jobID=1010, modelID=8467, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field12:n_256.modelParams|clParams|alpha_0.0422898752741.modelParams|sensorParams|encoders|_classifierInput|n_227):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [188] Experiment _NupicModelInfo(jobID=1010, modelID=8468, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0422898752741.modelParams|sensorParams|encoders|_classifierInput|n_227.modelParams|sensorParams|encoders|field13:n_256):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [189] Experiment _NupicModelInfo(jobID=1010, modelID=8469, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0422898752741.modelParams|sensorParams|encoders|field15:n_256.modelParams|sensorParams|encoders|_classifierInput|n_227):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [190] Experiment _NupicModelInfo(jobID=1010, modelID=8470, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|_classifierInput|n_227.modelParams|clParams|alpha_0.0422898752741.modelParams|sensorParams|encoders|field16:n_256):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [191] Experiment _NupicModelInfo(jobID=1010, modelID=8471, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field17:n_256.modelParams|clParams|alpha_0.0422898752741.modelParams|sensorParams|encoders|_classifierInput|n_227):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [192] Experiment _NupicModelInfo(jobID=1010, modelID=8472, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0468202278794.modelParams|sensorParams|encoders|_classifierInput|n_237.modelParams|sensorParams|encoders|field18:n_223):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [193] Experiment _NupicModelInfo(jobID=1010, modelID=8473, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0468202278794.modelParams|sensorParams|encoders|_classifierInput|n_237.modelParams|sensorParams|encoders|field19:n_223):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [194] Experiment _NupicModelInfo(jobID=1010, modelID=8474, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0422898752741.modelParams|sensorParams|encoders|_classifierInput|n_227.modelParams|sensorParams|encoders|field2:n_256):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [195] Experiment _NupicModelInfo(jobID=1010, modelID=8475, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0422898752741.modelParams|sensorParams|encoders|_classifierInput|n_227.modelParams|sensorParams|encoders|field20:n_256):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [196] Experiment _NupicModelInfo(jobID=1010, modelID=8476, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field21:n_256.modelParams|sensorParams|encoders|_classifierInput|n_227.modelParams|clParams|alpha_0.0422898752741):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [197] Experiment _NupicModelInfo(jobID=1010, modelID=8477, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0468202278794.modelParams|sensorParams|encoders|_classifierInput|n_227.modelParams|sensorParams|encoders|field22:n_233):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [198] Experiment _NupicModelInfo(jobID=1010, modelID=8478, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field23:n_256.modelParams|clParams|alpha_0.0422898752741.modelParams|sensorParams|encoders|_classifierInput|n_227):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# [199] Experiment _NupicModelInfo(jobID=1010, modelID=8479, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0422898752741.modelParams|sensorParams|encoders|field24:n_256.modelParams|sensorParams|encoders|_classifierInput|n_227):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.0
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  0.0
#
# --------------------------------------------------------------
# 200 experiments total (all completed successfully).
#
# WaitingToStart: 0
# Running: 0
# Completed: 200
#     ran to EOF: 200
#     ran to stop signal: 0
#     were orphaned: 0
#     killed off: 0
#     failed: 0
#
# Field Contributions:
# {   u'field1': 100.0,
#     u'field10': 100.0,
#     u'field11': 100.0,
#     u'field12': 100.0,
#     u'field13': 100.0,
#     u'field15': 100.0,
#     u'field16': 100.0,
#     u'field17': 100.0,
#     u'field18': 100.0,
#     u'field19': 100.0,
#     u'field2': 100.0,
#     u'field20': 100.0,
#     u'field21': 100.0,
#     u'field22': 100.0,
#     u'field23': 100.0,
#     u'field24': 100.0,
#     u'field3': 100.0,
#     u'field4': 100.0,
#     u'field5': 100.0,
#     u'field6': 100.0,
#     u'field7': 100.0,
#     u'field8': 100.0,
#     u'field9': 100.0}
#
# Best results on the optimization metric multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification (maximize=False):
# [1] Experiment _NupicModelInfo(jobID=1010, modelID=8039, status=completed, completionReason=eof, updateCounter=46, numRecords=4000) (modelParams|sensorParams|encoders|field10:n_272.modelParams|sensorParams|encoders|_classifierInput|n_275.modelParams|clParams|alpha_0.05005):
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:    0.0
#
# Total number of Records processed: 800000
#
# Total wall time for all models: 13893
#
# Generating description files for top 1 models...
# Generating description file for model 8030 at /home/polina/Documents/hse/course_work/model_0
# Generating model params file...
#
# Report csv saved in /home/polina/Documents/hse/course_work/default_Report.csv
# Elapsed time (h:mm:ss): 0:29:49
# Hypersearch ClientJobs job ID:  1010

# %%
from nupic.frameworks.opf.modelfactory import ModelFactory
model = ModelFactory.create(model_params)
model.enableInference({"predictedField": 'classification'})

# %%
model.save("/home/polina/Documents/hse/course_work/lab_data/24chan/model24_1")
#model.load("/home/polina/Documents/hse/course_work/lab_data/24chan/model24_1")

# %%
# Function return dataframe with 2 columns: classification value and predicted values,
# obtained with model.
# Parameters:
#  -- data_frame - pandas df
#  -- class_column - column from data_frame with class labels
#  -- model - model, obtained with nupic (class <nupic.frameworks.opf.clamodel.CLAModel>)
def predicted_values(data_frame, class_column, model):
    output = zip(np.asarray(class_column), np.zeros(len(class_column), dtype = int))
    output = pd.DataFrame(output)
    input_dict = data_frame.to_dict(orient = "index")
    for k in input_dict.keys():
        row = input_dict[k]
        result = model.run(row)
        output[1][k] = result.inferences['multiStepBestPredictions'][0]
    return output

def mean_error(init_class, predicted_class):
    return np.mean(np.array(init_class) != np.array(predicted_class))

# %%
test_output = predicted_values(testdf, testdf['classification'], model)
train_output =  predicted_values(traindf, traindf['classification'], model)
print test_output.head()
print train_output.head()
# Out:
#    0  1
# 0  1  0
# 1  1  0
# 2  1  0
# 3  1  0
# 4  1  0
#    0  1
# 0  1  0
# 1  1  0
# 2  1  0
# 3  1  0
# 4  1  0

# %%
print np.unique(test_output[1])
print np.unique(train_output[1])
# Out:
# [0 2 4]
# [0 2 4]

# %%
test_output[1] = test_output[1] // 2
train_output[1] = train_output[1] // 2

# %%
#print output.head()
print np.sum(np.array(test_output[1]) != np.array(testdf['classification']))
print test_output.shape
print np.array(test_output[1]) != np.array(testdf['classification'])
# Out:
# 59
# (33237, 2)
# [ True  True  True ..., False False False]

# %%
train_error = mean_error(train_output[0], train_output[1])
test_error  = mean_error(test_output[0], test_output[1])
print train_error, test_error
# Out:
# 0.00102252519265 0.00177513012606
