# %% [markdown]
# ## <center> Creating model with swarming and obtain result </center>
# ### <center> For resampled data (with frequency 1./5) </center>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.io
from operator import itemgetter
import pandas as pd
from sklearn.cross_validation import train_test_split

import csv
import nupic

# %%
traindf = pd.read_csv('./lab_data/24chan/24chan_test_resample.csv', header = 0, skiprows = [1,2])
testdf = pd.read_csv('./lab_data/24chan/24chan_test_resample.csv', header = 0, skiprows = [1,2])

print traindf.shape
print traindf.head()
# Out:
# (6648, 24)
#         field1       field2       field3      field4      field5       field6  \
# 0 -3507.041126 -3520.865399 -5942.130479  394.915448  277.220819 -1000.560192
# 1 -3081.025255 -3834.670319 -5949.310981  -27.361781  245.274163  -918.342229
# 2 -3158.239012 -3710.077808 -5844.795161  107.094675  282.692525  -919.889224
# 3 -3393.184569 -3565.773394 -5915.439466  338.627626  290.339420  -928.446531
# 4 -3077.195589 -3836.934617 -5962.347134  -31.087914  246.850113  -913.484781
#
#          field7       field8        field9      field10       ...        \
# 0 -10863.009935 -8838.866169 -45405.476110 -8144.264087       ...
# 1 -10973.724580 -9193.282094 -50937.552909 -8010.015127       ...
# 2 -10873.482240 -9044.823616 -50387.933246 -8038.342388       ...
# 3 -10831.143938 -8893.985946 -48502.439665 -8113.764082       ...
# 4 -10982.303469 -9195.587929 -50351.605631 -8011.228376       ...
#
#         field16      field17      field18     field19      field20  \
# 0 -30700.170450 -1231.175294  1102.004895  -12.640739 -7242.624273
# 1 -32534.726569 -1941.481671  1053.523716 -247.489187 -7268.377860
# 2 -31433.609019 -1691.839610  1080.702972 -160.783084 -7227.641702
# 3 -31007.990564 -1356.235925  1129.317073  -36.625460 -7245.332007
# 4 -32538.080009 -1949.340801  1053.882294 -248.211760 -7271.058809
#
#        field21      field22       field23   field24  classification
# 0 -3118.794105 -6860.227643 -13006.833512 -0.017882               0
# 1 -3811.868867 -6823.301583 -13153.171421 -0.017883               1
# 2 -3563.067468 -6785.736105 -13113.076246 -0.017881               1
# 3 -3236.130999 -6842.927796 -13003.360055 -0.017882               0
# 4 -3814.678057 -6823.465923 -13145.535560 -0.017880               1
#
# [5 rows x 24 columns]

# %%
traindf.describe()
# Out:
#             field1       field2       field3       field4       field5  \
# count  6648.000000  6648.000000  6648.000000  6648.000000  6648.000000
# mean  -3283.758236 -3657.441468 -5899.836536   192.675740   270.027254
# std     183.422006   130.736858    91.463915   164.691917    22.307758
# min   -4028.050150 -4083.630729 -6640.891347  -145.265758    -9.234217
# 25%   -3426.109413 -3723.472030 -5934.510699    83.203765   255.919938
# 50%   -3259.508142 -3634.853259 -5908.119403   183.528227   275.770843
# 75%   -3128.657265 -3555.769556 -5866.114315   351.176304   287.393998
# max     172.058130   119.404664   237.574377   467.762657   313.286609
#
#             field6        field7       field8        field9      field10  \
# count  6648.000000   6648.000000  6648.000000   6648.000000  6648.000000
# mean   -939.796587 -10883.221354 -8986.862999 -49183.201398 -8078.927329
# std      33.504212    162.197700   185.362651   2169.684182   128.837157
# min   -1085.404554 -12109.969675 -9775.742427 -53493.046353 -9109.152587
# 25%    -945.921271 -10907.984438 -9093.599862 -50640.768905 -8130.805816
# 50%    -930.272032 -10867.895509 -8959.483596 -50310.569360 -8081.073363
# 75%    -919.657166 -10847.542901 -8881.754043 -47978.186632 -8019.985516
# max      42.207568    419.307777   319.413228   1464.331622   332.042597
#
#             ...             field16      field17      field18      field19  \
# count       ...         6648.000000  6648.000000  6648.000000  6648.000000
# mean        ...       -31609.605410 -1560.452822  1094.065385  -118.305841
# std         ...          789.039972   274.890383    32.567570    89.813200
# min         ...       -33793.425717 -2213.031779   -45.188864  -285.204314
# 25%         ...       -32257.963854 -1758.646780  1064.765487  -178.312780
# 50%         ...       -31581.096693 -1524.772479  1104.018681  -109.815695
# 75%         ...       -31054.629670 -1321.232604  1114.970105   -35.171969
# max         ...         1114.432096    -2.952825  1219.769934    26.672521
#
#            field20      field21      field22       field23      field24  \
# count  6648.000000  6648.000000  6648.000000   6648.000000  6648.000000
# mean  -7244.232960 -3433.898351 -6817.931339 -13076.918685    -0.017878
# std     102.768514   264.324038   101.709721    190.118570     0.000249
# min   -8083.450903 -4097.144396 -7623.488932 -14459.074407    -0.019854
# 25%   -7257.343371 -3629.893563 -6847.388007 -13135.613660    -0.017882
# 50%   -7244.006759 -3419.435479 -6814.550205 -13063.958159    -0.017881
# 75%   -7233.346393 -3211.127123 -6785.895278 -13027.432076    -0.017881
# max     286.207118    78.217918   274.543825    504.794590     0.000701
#
#        classification
# count     6648.000000
# mean         1.000903
# std          0.819500
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          2.000000
#
# [8 rows x 24 columns]

# %%
num_fields = len(traindf.columns) 
# Exclude the column 'field14'
fields_names = ['field' + (str(i+1) if (i+1 < 14) else str(i+2)) for i in range(num_fields)] #+\
#    ['classification']
included_fields = []
for f in fields_names:
    field_dict = {'fieldName': f, 'fieldType': 'float', 'maxValue': 100000.0, 'minValue': -100000.0}
    included_fields.append(field_dict)

included_fields.append({'fieldName': 'classification', 'fieldType': 'int', 'maxValue': 2, 'minValue': 0})

# %%
SWARM_CONFIG = {
    "includedFields": included_fields,
    "streamDef": {
        "info": "classification_24channels",
        "version": 1,
        "streams": [
            {
                "info": "sine.csv",
                "source": "file:///home/polina/Documents/hse/course_work/lab_data/24chan/24chan_test_resample.csv",
                "columns": [
                  "*"
                ]
            }
        ]
    },
    "inferenceType": "NontemporalClassification",
    "inferenceArgs": {
        "predictionSteps": [
          0
        ],
        "predictedField": u'classification'
    },
    "swarmSize": "medium"
}

# %%
from nupic.swarming import permutations_runner
from nupic.swarming.permutations_runner import DEFAULT_OPTIONS
import nupic.swarming

# %%
def swarm_over_data():
    return nupic.swarming.permutations_runner.runWithConfig(SWARM_CONFIG, {'maxWorkers': 8, 'overwrite': True})

model_params = swarm_over_data()
# Out:
# Generating experiment files in directory: /home/polina/Documents/hse/course_work...
# Writing  313 lines...
# Writing  114 lines...
# done.
# None
# Successfully submitted new HyperSearch job, jobID=1011
# ##>> UPDATED WORKER STATE:
# {   u'activeSwarms': [   u'modelParams|sensorParams|encoders|field8',
#                          u'modelParams|sensorParams|encoders|field9',
#                          u'modelParams|sensorParams|encoders|field6',
#                          u'modelParams|sensorParams|encoders|field7',
#                          u'modelParams|sensorParams|encoders|field4',
#                          u'modelParams|sensorParams|encoders|field5',
#                          u'modelParams|sensorParams|encoders|field2',
#                          u'modelParams|sensorParams|encoders|field3',
#                          u'modelParams|sensorParams|encoders|field1',
#                          u'modelParams|sensorParams|encoders|field18',
#                          u'modelParams|sensorParams|encoders|field19',
#                          u'modelParams|sensorParams|encoders|field15',
#                          u'modelParams|sensorParams|encoders|field16',
#                          u'modelParams|sensorParams|encoders|field17',
#                          u'modelParams|sensorParams|encoders|field10',
#                          u'modelParams|sensorParams|encoders|field11',
#                          u'modelParams|sensorParams|encoders|field12',
#                          u'modelParams|sensorParams|encoders|field13',
#                          u'modelParams|sensorParams|encoders|field25',
#                          u'modelParams|sensorParams|encoders|field24',
#                          u'modelParams|sensorParams|encoders|field21',
#                          u'modelParams|sensorParams|encoders|field20',
#                          u'modelParams|sensorParams|encoders|field23',
#                          u'modelParams|sensorParams|encoders|field22'],
#     u'blackListedEncoders': [],
#     u'lastGoodSprint': None,
#     u'lastUpdateTime': 1464157588.223583,
#     u'searchOver': False,
#     u'sprints': [   {   u'bestErrScore': None,
#                         u'bestModelId': None,
#                         u'status': u'active'}],
#     u'swarms': {   u'modelParams|sensorParams|encoders|field1': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field10': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field11': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field12': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field13': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field15': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field16': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field17': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field18': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field19': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field2': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field20': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field21': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field22': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field23': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field24': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field25': {   u'bestErrScore': None,
#                                                                      u'bestModelId': None,
#                                                                      u'sprintIdx': 0,
#                                                                      u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field3': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field4': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field5': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field6': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field7': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field8': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'},
#                    u'modelParams|sensorParams|encoders|field9': {   u'bestErrScore': None,
#                                                                     u'bestModelId': None,
#                                                                     u'sprintIdx': 0,
#                                                                     u'status': u'active'}}}
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 100.0,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.5,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 100.0},
#     u'saved': False} (elapsed time: 15.4276 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 101.05263157894737,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.96,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 101.05263157894737},
#     u'saved': False} (elapsed time: 16.7352 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 91.83673469387755,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.9,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 91.83673469387755},
#     u'saved': False} (elapsed time: 17.7753 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 84.2809364548495,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.84,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 84.2809364548495},
#     u'saved': False} (elapsed time: 18.7976 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 82.7930174563591,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.83,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 82.7930174563591},
#     u'saved': False} (elapsed time: 19.8741 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 82.79352226720648,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.818,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 82.79352226720648},
#     u'saved': False} (elapsed time: 20.9005 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 82.14876033057851,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.8283333333333334,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 82.14876033057851},
#     u'saved': False} (elapsed time: 22.0085 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 80.1980198019802,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.81,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 80.1980198019802},
#     u'saved': False} (elapsed time: 23.0364 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 78.51758793969849,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.78125,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 78.51758793969849},
#     u'saved': False} (elapsed time: 24.0687 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 80.70953436807095,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.8088888888888889,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 80.70953436807095},
#     u'saved': False} (elapsed time: 25.3611 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 81.34920634920636,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.82,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 81.34920634920636},
#     u'saved': False} (elapsed time: 26.4486 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 79.6477495107632,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.814,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 79.6477495107632},
#     u'saved': False} (elapsed time: 27.5704 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 80.50930460333007,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.822,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 80.50930460333007},
#     u'saved': False} (elapsed time: 30.1939 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 82.58317025440313,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.844,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 82.58317025440313},
#     u'saved': False} (elapsed time: 31.2206 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 85.23290386521309,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.86,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 85.23290386521309},
#     u'saved': False} (elapsed time: 32.2405 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 86.35477582846003,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.886,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 86.35477582846003},
#     u'saved': False} (elapsed time: 33.2766 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 87.20238095238095,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.879,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 87.20238095238095},
#     u'saved': False} (elapsed time: 34.3155 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 91.01796407185628,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.912,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 91.01796407185628},
#     u'saved': False} (elapsed time: 35.3679 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 92.27005870841488,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.943,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 92.27005870841488},
#     u'saved': False} (elapsed time: 36.3789 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 90.94488188976378,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.924,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 90.94488188976378},
#     u'saved': False} (elapsed time: 37.4041 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 90.66534260178749,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.913,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 90.66534260178749},
#     u'saved': False} (elapsed time: 38.4361 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 90.8080808080808,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.899,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 90.8080808080808},
#     u'saved': False} (elapsed time: 39.8392 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 87.97595190380761,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.878,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 87.97595190380761},
#     u'saved': False} (elapsed time: 40.8607 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 88.68686868686869,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.878,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 88.68686868686869},
#     u'saved': False} (elapsed time: 41.9079 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 87.64940239043824,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.88,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 87.64940239043824},
#     u'saved': False} (elapsed time: 42.926 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 86.33165829145729,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.859,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 86.33165829145729},
#     u'saved': False} (elapsed time: 43.9562 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 85.92814371257485,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.861,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 85.92814371257485},
#     u'saved': False} (elapsed time: 44.9885 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 84.3313373253493,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.845,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 84.3313373253493},
#     u'saved': False} (elapsed time: 46.0126 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 83.91038696537679,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.824,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 83.91038696537679},
#     u'saved': False} (elapsed time: 47.0646 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 83.63821138211382,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.823,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 83.63821138211382},
#     u'saved': False} (elapsed time: 48.0979 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 84.46502057613169,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.821,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 84.46502057613169},
#     u'saved': False} (elapsed time: 49.1246 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 85.59670781893004,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.832,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 85.59670781893004},
#     u'saved': False} (elapsed time: 50.1566 secs)
# <jobID: 1011> 3  models finished [success: 3; EOF: 3; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8546,
#     u'bestValue': 86.70820353063344,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.835,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 86.70820353063344},
#     u'saved': True} (elapsed time: 51.1852 secs)
# <jobID: 1011> 4  models finished [success: 4; EOF: 4; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1011> 5  models finished [success: 5; EOF: 5; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1011> 6  models finished [success: 6; EOF: 6; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8480,
#     u'bestValue': 84.63136033229492,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.815,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 84.63136033229492},
#     u'saved': True} (elapsed time: 57.34 secs)
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8646,
#     u'bestValue': 77.0508826583593,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.742,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 77.0508826583593},
#     u'saved': True} (elapsed time: 59.3933 secs)
# <jobID: 1011> 8  models finished [success: 8; EOF: 8; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1011> 10  models finished [success: 10; EOF: 10; stopped: 0; killed: 0; error: 0; orphaned: 0; unknown: 0]
# <jobID: 1011> 12  models finished [success: 11; EOF: 11; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# ERROR MESSAGE: Exception occurred while running model 8707: ValueError("Unknown field name 'field25' in input record. Known fields are 'classification, field19, field8, field9, field2, field3, field1, field6, field7, field4, field5, field10, field11, field12, field13, field15, field16, field17, field18, field24, field21, field20, field23, field22'.\nThis could be because input headers are mislabeled, or because input data rows do not contain a value for 'field25'.",) (<type 'exceptions.ValueError'>)
# Traceback (most recent call last):
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/swarming/hypersearch/utils.py", line 435, in runModelGivenBaseAndParams
#     (completionReason, completionMsg) = runner.run()
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/swarming/ModelRunner.py", line 282, in run
#     self.__runTaskMainLoop(numIters, learningOffAt=learningOffAt)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/swarming/ModelRunner.py", line 360, in __runTaskMainLoop
#     result = self._model.run(inputRecord=inputRecord)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/frameworks/opf/clamodel.py", line 395, in run
#     self._sensorCompute(inputRecord)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/frameworks/opf/clamodel.py", line 480, in _sensorCompute
#     sensor.compute()
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/engine/__init__.py", line 458, in compute
#     return self._region.compute()
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic.bindings-0.4.3.dev0-py2.7-linux-x86_64.egg/nupic/bindings/engine_internal.py", line 1393, in compute
#     return _engine_internal.Region_compute(self)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic.bindings-0.4.3.dev0-py2.7-linux-x86_64.egg/nupic/bindings/regions/PyRegion.py", line 178, in guardedCompute
#     return self.compute(inputs, DictReadOnlyWrapper(outputs))
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/regions/RecordSensor.py", line 346, in compute
#     self.encoder.encodeIntoArray(data, outputs["dataOut"])
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/encoders/multi.py", line 95, in encodeIntoArray
#     encoder.encodeIntoArray(self._getInputValue(obj, name), output[offset:])
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/encoders/base.py", line 212, in _getInputValue
#     fieldName, knownFields, fieldName
# ValueError: Unknown field name 'field25' in input record. Known fields are 'classification, field19, field8, field9, field2, field3, field1, field6, field7, field4, field5, field10, field11, field12, field13, field15, field16, field17, field18, field24, field21, field20, field23, field22'.
# This could be because input headers are mislabeled, or because input data rows do not contain a value for 'field25'.
#
# <jobID: 1011> 14  models finished [success: 13; EOF: 13; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 15  models finished [success: 14; EOF: 14; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 16  models finished [success: 15; EOF: 15; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 17  models finished [success: 16; EOF: 16; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 18  models finished [success: 17; EOF: 17; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 19  models finished [success: 18; EOF: 18; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 20  models finished [success: 19; EOF: 19; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 23  models finished [success: 22; EOF: 22; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 24  models finished [success: 23; EOF: 23; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8773,
#     u'bestValue': 48.494288681204566,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.467,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 48.494288681204566},
#     u'saved': True} (elapsed time: 134.924 secs)
# <jobID: 1011> 25  models finished [success: 24; EOF: 24; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 26  models finished [success: 25; EOF: 25; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 27  models finished [success: 26; EOF: 26; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 28  models finished [success: 27; EOF: 27; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 29  models finished [success: 28; EOF: 28; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 30  models finished [success: 29; EOF: 29; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 31  models finished [success: 30; EOF: 30; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 32  models finished [success: 31; EOF: 31; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 33  models finished [success: 32; EOF: 32; stopped: 0; killed: 0; ERROR: 1; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 34  models finished [success: 32; EOF: 32; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# ERROR MESSAGE: Exception occurred while running model 8850: ValueError("Unknown field name 'field25' in input record. Known fields are 'classification, field19, field8, field9, field2, field3, field1, field6, field7, field4, field5, field10, field11, field12, field13, field15, field16, field17, field18, field24, field21, field20, field23, field22'.\nThis could be because input headers are mislabeled, or because input data rows do not contain a value for 'field25'.",) (<type 'exceptions.ValueError'>)
# Traceback (most recent call last):
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/swarming/hypersearch/utils.py", line 435, in runModelGivenBaseAndParams
#     (completionReason, completionMsg) = runner.run()
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/swarming/ModelRunner.py", line 282, in run
#     self.__runTaskMainLoop(numIters, learningOffAt=learningOffAt)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/swarming/ModelRunner.py", line 360, in __runTaskMainLoop
#     result = self._model.run(inputRecord=inputRecord)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/frameworks/opf/clamodel.py", line 395, in run
#     self._sensorCompute(inputRecord)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/frameworks/opf/clamodel.py", line 480, in _sensorCompute
#     sensor.compute()
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/engine/__init__.py", line 458, in compute
#     return self._region.compute()
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic.bindings-0.4.3.dev0-py2.7-linux-x86_64.egg/nupic/bindings/engine_internal.py", line 1393, in compute
#     return _engine_internal.Region_compute(self)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic.bindings-0.4.3.dev0-py2.7-linux-x86_64.egg/nupic/bindings/regions/PyRegion.py", line 178, in guardedCompute
#     return self.compute(inputs, DictReadOnlyWrapper(outputs))
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/regions/RecordSensor.py", line 346, in compute
#     self.encoder.encodeIntoArray(data, outputs["dataOut"])
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/encoders/multi.py", line 95, in encodeIntoArray
#     encoder.encodeIntoArray(self._getInputValue(obj, name), output[offset:])
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/encoders/base.py", line 212, in _getInputValue
#     fieldName, knownFields, fieldName
# ValueError: Unknown field name 'field25' in input record. Known fields are 'classification, field19, field8, field9, field2, field3, field1, field6, field7, field4, field5, field10, field11, field12, field13, field15, field16, field17, field18, field24, field21, field20, field23, field22'.
# This could be because input headers are mislabeled, or because input data rows do not contain a value for 'field25'.
#
# <jobID: 1011> 35  models finished [success: 33; EOF: 33; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 36  models finished [success: 34; EOF: 34; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 37  models finished [success: 35; EOF: 35; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 38  models finished [success: 36; EOF: 36; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 39  models finished [success: 37; EOF: 37; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 40  models finished [success: 38; EOF: 38; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 41  models finished [success: 39; EOF: 39; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 42  models finished [success: 40; EOF: 40; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 43  models finished [success: 41; EOF: 41; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 44  models finished [success: 42; EOF: 42; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 45  models finished [success: 43; EOF: 43; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 46  models finished [success: 44; EOF: 44; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 47  models finished [success: 45; EOF: 45; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 48  models finished [success: 46; EOF: 46; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 49  models finished [success: 47; EOF: 47; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 50  models finished [success: 48; EOF: 48; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 51  models finished [success: 49; EOF: 49; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 54  models finished [success: 52; EOF: 52; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 55  models finished [success: 53; EOF: 53; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 56  models finished [success: 54; EOF: 54; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 57  models finished [success: 55; EOF: 55; stopped: 0; killed: 0; ERROR: 2; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 58  models finished [success: 55; EOF: 55; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# ERROR MESSAGE: Exception occurred while running model 8904: ValueError("Unknown field name 'field25' in input record. Known fields are 'classification, field19, field8, field9, field2, field3, field1, field6, field7, field4, field5, field10, field11, field12, field13, field15, field16, field17, field18, field24, field21, field20, field23, field22'.\nThis could be because input headers are mislabeled, or because input data rows do not contain a value for 'field25'.",) (<type 'exceptions.ValueError'>)
# Traceback (most recent call last):
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/swarming/hypersearch/utils.py", line 435, in runModelGivenBaseAndParams
#     (completionReason, completionMsg) = runner.run()
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/swarming/ModelRunner.py", line 282, in run
#     self.__runTaskMainLoop(numIters, learningOffAt=learningOffAt)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/swarming/ModelRunner.py", line 360, in __runTaskMainLoop
#     result = self._model.run(inputRecord=inputRecord)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/frameworks/opf/clamodel.py", line 395, in run
#     self._sensorCompute(inputRecord)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/frameworks/opf/clamodel.py", line 480, in _sensorCompute
#     sensor.compute()
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/engine/__init__.py", line 458, in compute
#     return self._region.compute()
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic.bindings-0.4.3.dev0-py2.7-linux-x86_64.egg/nupic/bindings/engine_internal.py", line 1393, in compute
#     return _engine_internal.Region_compute(self)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic.bindings-0.4.3.dev0-py2.7-linux-x86_64.egg/nupic/bindings/regions/PyRegion.py", line 178, in guardedCompute
#     return self.compute(inputs, DictReadOnlyWrapper(outputs))
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/regions/RecordSensor.py", line 346, in compute
#     self.encoder.encodeIntoArray(data, outputs["dataOut"])
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/encoders/multi.py", line 95, in encodeIntoArray
#     encoder.encodeIntoArray(self._getInputValue(obj, name), output[offset:])
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/encoders/base.py", line 212, in _getInputValue
#     fieldName, knownFields, fieldName
# ValueError: Unknown field name 'field25' in input record. Known fields are 'classification, field19, field8, field9, field2, field3, field1, field6, field7, field4, field5, field10, field11, field12, field13, field15, field16, field17, field18, field24, field21, field20, field23, field22'.
# This could be because input headers are mislabeled, or because input data rows do not contain a value for 'field25'.
#
# <jobID: 1011> 59  models finished [success: 56; EOF: 56; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 60  models finished [success: 57; EOF: 57; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 61  models finished [success: 58; EOF: 58; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 62  models finished [success: 59; EOF: 59; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 63  models finished [success: 60; EOF: 60; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 64  models finished [success: 61; EOF: 61; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 65  models finished [success: 62; EOF: 62; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 66  models finished [success: 63; EOF: 63; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 67  models finished [success: 64; EOF: 64; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 68  models finished [success: 65; EOF: 65; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 69  models finished [success: 66; EOF: 66; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 71  models finished [success: 68; EOF: 68; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 72  models finished [success: 69; EOF: 69; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 73  models finished [success: 70; EOF: 70; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# ####>> UPDATED JOB RESULTS:
# {   u'bestModel': 8911,
#     u'bestValue': 40.809968847352025,
#     u'metrics': {   u"multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification": 0.393,
#                     u"multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification": 40.809968847352025},
#     u'saved': True} (elapsed time: 481.209 secs)
# <jobID: 1011> 74  models finished [success: 71; EOF: 71; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 75  models finished [success: 72; EOF: 72; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 76  models finished [success: 73; EOF: 73; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 77  models finished [success: 74; EOF: 74; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 78  models finished [success: 75; EOF: 75; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 79  models finished [success: 76; EOF: 76; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 80  models finished [success: 77; EOF: 77; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 81  models finished [success: 78; EOF: 78; stopped: 0; killed: 0; ERROR: 3; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 82  models finished [success: 78; EOF: 78; stopped: 0; killed: 0; ERROR: 4; ORPHANED: 0; unknown: 0]
# ERROR MESSAGE: Exception occurred while running model 8948: ValueError("Unknown field name 'field25' in input record. Known fields are 'classification, field19, field8, field9, field2, field3, field1, field6, field7, field4, field5, field10, field11, field12, field13, field15, field16, field17, field18, field24, field21, field20, field23, field22'.\nThis could be because input headers are mislabeled, or because input data rows do not contain a value for 'field25'.",) (<type 'exceptions.ValueError'>)
# Traceback (most recent call last):
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/swarming/hypersearch/utils.py", line 435, in runModelGivenBaseAndParams
#     (completionReason, completionMsg) = runner.run()
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/swarming/ModelRunner.py", line 282, in run
#     self.__runTaskMainLoop(numIters, learningOffAt=learningOffAt)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/swarming/ModelRunner.py", line 360, in __runTaskMainLoop
#     result = self._model.run(inputRecord=inputRecord)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/frameworks/opf/clamodel.py", line 395, in run
#     self._sensorCompute(inputRecord)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/frameworks/opf/clamodel.py", line 480, in _sensorCompute
#     sensor.compute()
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/engine/__init__.py", line 458, in compute
#     return self._region.compute()
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic.bindings-0.4.3.dev0-py2.7-linux-x86_64.egg/nupic/bindings/engine_internal.py", line 1393, in compute
#     return _engine_internal.Region_compute(self)
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic.bindings-0.4.3.dev0-py2.7-linux-x86_64.egg/nupic/bindings/regions/PyRegion.py", line 178, in guardedCompute
#     return self.compute(inputs, DictReadOnlyWrapper(outputs))
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/regions/RecordSensor.py", line 346, in compute
#     self.encoder.encodeIntoArray(data, outputs["dataOut"])
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/encoders/multi.py", line 95, in encodeIntoArray
#     encoder.encodeIntoArray(self._getInputValue(obj, name), output[offset:])
#   File "/home/polina/.local/lib/python2.7/site-packages/nupic-0.5.3.dev0-py2.7.egg/nupic/encoders/base.py", line 212, in _getInputValue
#     fieldName, knownFields, fieldName
# ValueError: Unknown field name 'field25' in input record. Known fields are 'classification, field19, field8, field9, field2, field3, field1, field6, field7, field4, field5, field10, field11, field12, field13, field15, field16, field17, field18, field24, field21, field20, field23, field22'.
# This could be because input headers are mislabeled, or because input data rows do not contain a value for 'field25'.
#
# <jobID: 1011> 83  models finished [success: 79; EOF: 79; stopped: 0; killed: 0; ERROR: 4; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 84  models finished [success: 80; EOF: 80; stopped: 0; killed: 0; ERROR: 4; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 85  models finished [success: 81; EOF: 81; stopped: 0; killed: 0; ERROR: 4; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 86  models finished [success: 82; EOF: 82; stopped: 0; killed: 0; ERROR: 4; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 87  models finished [success: 83; EOF: 83; stopped: 0; killed: 0; ERROR: 4; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 88  models finished [success: 84; EOF: 84; stopped: 0; killed: 0; ERROR: 4; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 89  models finished [success: 85; EOF: 85; stopped: 0; killed: 0; ERROR: 4; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 90  models finished [success: 86; EOF: 86; stopped: 0; killed: 0; ERROR: 4; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 91  models finished [success: 87; EOF: 87; stopped: 0; killed: 0; ERROR: 4; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 92  models finished [success: 88; EOF: 88; stopped: 0; killed: 0; ERROR: 4; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 93  models finished [success: 89; EOF: 89; stopped: 0; killed: 0; ERROR: 4; ORPHANED: 0; unknown: 0]
# <jobID: 1011> 94  models finished [success: 90; EOF: 90; stopped: 0; killed: 0; ERROR: 4; ORPHANED: 0; unknown: 0]
# ...
#
# [181] Experiment _NupicModelInfo(jobID=1011, modelID=9092, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0663686218057.modelParams|sensorParams|encoders|_classifierInput|n_255.modelParams|sensorParams|encoders|field22:n_297):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.829
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  86.08515057113188
#
# [182] Experiment _NupicModelInfo(jobID=1011, modelID=9093, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field23:n_305.modelParams|clParams|alpha_0.0650172245066.modelParams|sensorParams|encoders|_classifierInput|n_317):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.809
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  84.00830737279335
#
# [183] Experiment _NupicModelInfo(jobID=1011, modelID=9094, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0650172245066.modelParams|sensorParams|encoders|field24:n_305.modelParams|sensorParams|encoders|_classifierInput|n_317):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.828
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  85.98130841121495
#
# [184] Experiment _NupicModelInfo(jobID=1011, modelID=9095, status=completed, completionReason=error, updateCounter=3, numRecords=0)
# (modelParams|clParams|alpha_0.1.modelParams|sensorParams|encoders|_classifierInput|n_496.modelParams|sensorParams|encoders|field25:n_521):
# [185] Experiment _NupicModelInfo(jobID=1011, modelID=9096, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0709662036916.modelParams|sensorParams|encoders|field3:n_467.modelParams|sensorParams|encoders|_classifierInput|n_320):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.839
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  87.12357217030114
#
# [186] Experiment _NupicModelInfo(jobID=1011, modelID=9097, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field4:n_521.modelParams|clParams|alpha_0.1.modelParams|sensorParams|encoders|_classifierInput|n_496):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.8
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  83.07372793354102
#
# [187] Experiment _NupicModelInfo(jobID=1011, modelID=9098, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0650172245066.modelParams|sensorParams|encoders|_classifierInput|n_317.modelParams|sensorParams|encoders|field5:n_305):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.828
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  85.98130841121495
#
# [188] Experiment _NupicModelInfo(jobID=1011, modelID=9099, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field6:n_521.modelParams|sensorParams|encoders|_classifierInput|n_496.modelParams|clParams|alpha_0.1):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.831
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  86.29283489096574
#
# [189] Experiment _NupicModelInfo(jobID=1011, modelID=9100, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0650172245066.modelParams|sensorParams|encoders|_classifierInput|n_317.modelParams|sensorParams|encoders|field7:n_305):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.822
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  85.35825545171339
#
# [190] Experiment _NupicModelInfo(jobID=1011, modelID=9101, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|_classifierInput|n_478.modelParams|clParams|alpha_0.1.modelParams|sensorParams|encoders|field8:n_521):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.81
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  84.11214953271028
#
# [191] Experiment _NupicModelInfo(jobID=1011, modelID=9102, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field9:n_521.modelParams|clParams|alpha_0.0907170969725.modelParams|sensorParams|encoders|_classifierInput|n_401):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.386
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  40.08307372793354
#
# [192] Experiment _NupicModelInfo(jobID=1011, modelID=9103, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field1:n_454.modelParams|clParams|alpha_0.1.modelParams|sensorParams|encoders|_classifierInput|n_426):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.809
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  84.00830737279335
#
# [193] Experiment _NupicModelInfo(jobID=1011, modelID=9104, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field10:n_328.modelParams|sensorParams|encoders|_classifierInput|n_185.modelParams|clParams|alpha_0.0368801148891):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.849
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  88.1619937694704
#
# [194] Experiment _NupicModelInfo(jobID=1011, modelID=9105, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0555999929715.modelParams|sensorParams|encoders|_classifierInput|n_261.modelParams|sensorParams|encoders|field11:n_291):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.833
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  86.50051921079958
#
# [195] Experiment _NupicModelInfo(jobID=1011, modelID=9106, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field12:n_291.modelParams|clParams|alpha_0.0555999929715.modelParams|sensorParams|encoders|_classifierInput|n_261):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.833
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  86.50051921079958
#
# [196] Experiment _NupicModelInfo(jobID=1011, modelID=9107, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0526808295139.modelParams|sensorParams|encoders|_classifierInput|n_250.modelParams|sensorParams|encoders|field13:n_443):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.775
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  80.47767393561786
#
# [197] Experiment _NupicModelInfo(jobID=1011, modelID=9108, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0555999929715.modelParams|sensorParams|encoders|field15:n_291.modelParams|sensorParams|encoders|_classifierInput|n_261):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.796
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  82.65835929387332
#
# [198] Experiment _NupicModelInfo(jobID=1011, modelID=9109, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|_classifierInput|n_331.modelParams|clParams|alpha_0.0724317227948.modelParams|sensorParams|encoders|field16:n_521):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.668
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  69.36656282450674
#
# [199] Experiment _NupicModelInfo(jobID=1011, modelID=9110, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field17:n_521.modelParams|clParams|alpha_0.0724317227948.modelParams|sensorParams|encoders|_classifierInput|n_331):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.736
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  76.42782969885774
#
# [200] Experiment _NupicModelInfo(jobID=1011, modelID=9111, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0735604557587.modelParams|sensorParams|encoders|_classifierInput|n_346.modelParams|sensorParams|encoders|field18:n_323):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.838
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  87.01973001038422
#
# [201] Experiment _NupicModelInfo(jobID=1011, modelID=9112, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0521682734552.modelParams|sensorParams|encoders|_classifierInput|n_258.modelParams|sensorParams|encoders|field19:n_242):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.812
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  84.31983385254414
#
# [202] Experiment _NupicModelInfo(jobID=1011, modelID=9113, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0544442741012.modelParams|sensorParams|encoders|_classifierInput|n_251.modelParams|sensorParams|encoders|field2:n_482):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.83
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  86.1889927310488
#
# [203] Experiment _NupicModelInfo(jobID=1011, modelID=9114, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0467318503289.modelParams|sensorParams|encoders|_classifierInput|n_246.modelParams|sensorParams|encoders|field20:n_281):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.848
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  88.05815160955348
#
# [204] Experiment _NupicModelInfo(jobID=1011, modelID=9115, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field21:n_482.modelParams|sensorParams|encoders|_classifierInput|n_251.modelParams|clParams|alpha_0.0544442741012):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.81
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  84.11214953271028
#
# [205] Experiment _NupicModelInfo(jobID=1011, modelID=9117, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0616743054438.modelParams|sensorParams|encoders|_classifierInput|n_185.modelParams|sensorParams|encoders|field22:n_205):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.829
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  86.08515057113188
#
# [206] Experiment _NupicModelInfo(jobID=1011, modelID=9118, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|sensorParams|encoders|field23:n_291.modelParams|clParams|alpha_0.0555999929715.modelParams|sensorParams|encoders|_classifierInput|n_261):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.833
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  86.50051921079958
#
# [207] Experiment _NupicModelInfo(jobID=1011, modelID=9119, status=completed, completionReason=eof, updateCounter=45, numRecords=4000)
# (modelParams|clParams|alpha_0.0555999929715.modelParams|sensorParams|encoders|field24:n_291.modelParams|sensorParams|encoders|_classifierInput|n_261):
#   multiStepBestPredictions:multiStep:errorMetric='aae':steps=[0]:window=1000:field=classification:      0.833
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:  86.50051921079958
#
# --------------------------------------------------------------
# 208 experiments total (WARNING: 8 models have not completed or there were errors).
#
# WaitingToStart: 0
# Running: 0
# Completed: 208
#     ran to EOF: 200
#     ran to stop signal: 0
#     were orphaned: 0
#     killed off: 0
#     failed: 8
#
# Field Contributions:
# {   u'field1': 0.0,
#     u'field10': -4.609475032010237,
#     u'field11': -6.017925736235592,
#     u'field12': -4.9935979513444275,
#     u'field13': 0.7682458386683816,
#     u'field15': -1.9206145966709365,
#     u'field16': 14.46862996158772,
#     u'field17': 5.76184379001281,
#     u'field18': -5.761843790012792,
#     u'field19': -3.329065300896291,
#     u'field2': -3.969270166453264,
#     u'field20': -5.24967989756721,
#     u'field21': 4.481434058898846,
#     u'field22': -2.1766965428937186,
#     u'field23': -3.5851472471190733,
#     u'field24': -6.017925736235592,
#     u'field25': -inf,
#     u'field3': -0.5121638924455819,
#     u'field4': -2.4327784891165183,
#     u'field5': -6.017925736235592,
#     u'field6': -6.402048655569781,
#     u'field7': -5.1216389244558185,
#     u'field8': -3.5851472471190733,
#     u'field9': 51.21638924455825}
#
# Best results on the optimization metric multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification (maximize=False):
# [167] Experiment _NupicModelInfo(jobID=1011, modelID=9067, status=completed, completionReason=eof, updateCounter=47, numRecords=4000) (modelParams|sensorParams|encoders|field9:n_521.modelParams|clParams|alpha_0.0839445010964.modelParams|sensorParams|encoders|_classifierInput|n_403):
#   multiStepBestPredictions:multiStep:errorMetric='altMAPE':steps=[0]:window=1000:field=classification:    39.5638629283
#
# Total number of Records processed: 800000
#
# Total wall time for all models: 12172
#
# Generating description files for top 1 models...
# Generating description file for model 9067 at /home/polina/Documents/hse/course_work/model_0
# Generating model params file...
#
# Report csv saved in /home/polina/Documents/hse/course_work/default_Report.csv
# Previous report csv file was backed up to /home/polina/Documents/hse/course_work/default_Report.0.csv
# Elapsed time (h:mm:ss): 0:27:05
# Hypersearch ClientJobs job ID:  1011

# %%
from nupic.frameworks.opf.modelfactory import ModelFactory
model = ModelFactory.create(model_params)
model.enableInference({"predictedField": 'classification'})

# %%
model.save("/home/polina/Documents/hse/course_work/lab_data/24chan/model24_resample")
#model.load("/home/polina/Documents/hse/course_work/lab_data/24chan/model24_resample")

# %%
# Function return dataframe with 2 columns: classification value and predicted values,
# obtained with model.
# Parameters:
#  -- data_frame - pandas df
#  -- class_column - column from data_frame with class labels
#  -- model - model, obtained with nupic (class <nupic.frameworks.opf.clamodel.CLAModel>)
def predicted_values(data_frame, class_column, model):
    output = zip(np.asarray(class_column), np.zeros(len(class_column), dtype = int))
    output = pd.DataFrame(output)
    input_dict = data_frame.to_dict(orient = "index")
    for k in input_dict.keys():
        row = input_dict[k]
        result = model.run(row)
        output[1][k] = result.inferences['multiStepBestPredictions'][0]
    return output

def mean_error(init_class, predicted_class):
    return np.mean(np.array(init_class) != np.array(predicted_class))

# %%
test_output = predicted_values(testdf, testdf['classification'], model)
train_output =  predicted_values(traindf, traindf['classification'], model)
print test_output.head()
print train_output.head()
print np.unique(test_output[1])
print np.unique(train_output[1])
# Out:
#    0    1
# 0  0    0
# 1  1    0
# 2  1  191
# 3  0  191
# 4  1  191
#    0    1
# 0  0    0
# 1  1  191
# 2  1  191
# 3  0  191
# 4  1  191
# [  0 191 382]
# [  0 191 382]

# %%
test_output[1] = test_output[1] // 191
train_output[1] = train_output[1] // 191
print np.unique(test_output[1])
print np.unique(train_output[1])
# Out:
# [0 1 2]
# [0 1 2]

# %%
train_error = mean_error(train_output[0], train_output[1])
test_error  = mean_error(test_output[0], test_output[1])
print train_error, test_error
# Out:
# 0.37725631769 0.377707581227
